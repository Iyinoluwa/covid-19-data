# %% [markdown]
# <a href="https://colab.research.google.com/github/Iyinoluwa/covid-19-data/blob/master/Copy_of_coron_virus_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Covid19 Data Analysis Notebook
# ------------------------------------------

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Task 2.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
happiness_report_csv = pd.read_csv('/content/gdrive/My Drive/worldwide_happiness_report.csv')

happiness_report_csv.head(10)
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
# 5             6       Switzerland  ...       0.263                      0.343
# 6             7            Sweden  ...       0.267                      0.373
# 7             8       New Zealand  ...       0.330                      0.380
# 8             9            Canada  ...       0.285                      0.308
# 9            10           Austria  ...       0.244                      0.226
#
# [10 rows x 9 columns]

# %%
pd.read_csv('/content/gdrive/My Drive/covid19_Confirmed_dataset.csv')
# Out:
#     Province/State         Country/Region        Lat  ...  4/28/20  4/29/20  4/30/20
# 0              NaN            Afghanistan  33.000000  ...     1828     1939     2171
# 1              NaN                Albania  41.153300  ...      750      766      773
# 2              NaN                Algeria  28.033900  ...     3649     3848     4006
# 3              NaN                Andorra  42.506300  ...      743      743      745
# 4              NaN                 Angola -11.202700  ...       27       27       27
# ..             ...                    ...        ...  ...      ...      ...      ...
# 261            NaN         Western Sahara  24.215500  ...        6        6        6
# 262            NaN  Sao Tome and Principe   0.186360  ...        8        8       14
# 263            NaN                  Yemen  15.552727  ...        1        6        6
# 264            NaN                Comoros -11.645500  ...        0        0        1
# 265            NaN             Tajikistan  38.861034  ...        0        0       15
#
# [266 rows x 104 columns]

# %%
corona_dataset_csv = pd.read_csv('/content/gdrive/My Drive/covid19_deaths_dataset.csv')
corona_dataset_csv.head(15)
# Out:
#                   Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                            NaN          Afghanistan  ...       60       64
# 1                            NaN              Albania  ...       30       31
# 2                            NaN              Algeria  ...      444      450
# 3                            NaN              Andorra  ...       42       42
# 4                            NaN               Angola  ...        2        2
# 5                            NaN  Antigua and Barbuda  ...        3        3
# 6                            NaN            Argentina  ...      214      218
# 7                            NaN              Armenia  ...       30       32
# 8   Australian Capital Territory            Australia  ...        3        3
# 9                New South Wales            Australia  ...       40       41
# 10            Northern Territory            Australia  ...        0        0
# 11                    Queensland            Australia  ...        6        6
# 12               South Australia            Australia  ...        4        4
# 13                      Tasmania            Australia  ...       12       13
# 14                      Victoria            Australia  ...       18       18
#
# [15 rows x 104 columns]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
corona_dataset_csv = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
corona_dataset_csv.head(15)

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
corona_dataset_csv.drop(["Lat","Long"], axis=1,inplace= True)

# %%
 corona_dataset_csv.head(5)
# Out:
#   Province/State Country/Region  1/22/20  ...  4/28/20  4/29/20  4/30/20
# 0            NaN    Afghanistan        0  ...       58       60       64
# 1            NaN        Albania        0  ...       30       30       31
# 2            NaN        Algeria        0  ...      437      444      450
# 3            NaN        Andorra        0  ...       41       42       42
# 4            NaN         Angola        0  ...        2        2        2
#
# [5 rows x 102 columns]

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-06cc07508d05> in <module>()
# ----> 1 corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
#
# NameError: name 'corona_dataset_csv' is not defined

# %%
corona_dataset_aggregated.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2b9c4d810a64> in <module>()
# ----> 1 corona_dataset_aggregated.head()
#
# NameError: name 'corona_dataset_aggregated' is not defined

# %%
corona_dataset_aggregated.shape

# %% [markdown]
# ### Task 2.4: Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
#to visualize data to a particualr country
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
corona_dataset_aggregated.loc["Spain"].plot()
plt.legend()

# %% [markdown]
# ### Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_aggregated.loc['China'].plot()

# %%
#to plot for the first three days
corona_dataset_aggregated.loc["China"][:3].plot()

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve

# %%
#finding the rate of the curve
corona_dataset_aggregated.loc["China"].diff().plot()
#this shows infection rate day by day

# %% [markdown]
# ### task 3.2: find maxmimum infection rate for China

# %%
#for a single day
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 1290.0

# %%
corona_dataset_aggregated.loc["Italy"].diff().max()
# Out:
# 919.0

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 961.0

# %% [markdown]
# ### Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
#add a FOR LOOP for each country
for c in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
    #immediaely appends it
    
#max_infection_rates
corona_dataset_aggregated["max_infection_rate"] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/29/20  4/30/20  max_infection_rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...       60       64                 7.0
# Albania               0        0        0  ...       30       31                 4.0
# Algeria               0        0        0  ...      444      450                30.0
# Andorra               0        0        0  ...       42       42                 4.0
# Angola                0        0        0  ...        2        2                 2.0
#
# [5 rows x 101 columns]

# %% [markdown]
# ### Task 3.4: create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rate"])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                    7.0
# Albania                        4.0
# Algeria                       30.0
# Andorra                        4.0
# Angola                         2.0

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
happiness_report_csv = pd.read_csv("Datasets/worldwide_happiness_report.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-98d2d19a0e8b> in <module>()
# ----> 1 happiness_report_csv = pd.read_csv("Datasets/worldwide_happiness_report.csv")
#
# NameError: name 'pd' is not defined

# %%
happiness_report_csv.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7febf027ba9c> in <module>()
# ----> 1 happiness_report_csv.head(10)
#
# NameError: name 'happiness_report_csv' is not defined

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
useless_cols = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
happiness_report_csv.drop(useless_cols,axis=1,inplace=True)
happiness_report_csv.head()
# Out:
#   Country or region  ...  Freedom to make life choices
# 0           Finland  ...                         0.596
# 1           Denmark  ...                         0.592
# 2            Norway  ...                         0.603
# 3           Iceland  ...                         0.591
# 4       Netherlands  ...                         0.557
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe

# %%
#making the country the indices of the table for easy joining
happiness_report_csv.set_index("Country or region",inplace=True)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %% [markdown]
# ### Task4.4: now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
#now to join corona and world happiness report together
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                    7.0
# Albania                        4.0
# Algeria                       30.0
# Andorra                        4.0
# Angola                         2.0

# %%
corona_data.shape
# Out:
# (187, 1)

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %%
happiness_report_csv.shape
# Out:
# (156, 4)

# %% [markdown]
# best way is to use inner join when joining both data as the number of countries in both isnt equal to each other

# %%
data = corona_data.join(happiness_report_csv,how="inner")
data.head()
# Out:
#              max_infection_rate  ...  Freedom to make life choices
# Afghanistan                 7.0  ...                         0.000
# Albania                     4.0  ...                         0.383
# Algeria                    30.0  ...                         0.086
# Argentina                  13.0  ...                         0.471
# Armenia                     3.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# need to knoe if deris a correlation btw the column representing diff life factors and the column for spread of the infection

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
data.corr()
# Out:
#                               max_infection_rate  ...  Freedom to make life choices
# max_infection_rate                      1.000000  ...                      0.080166
# GDP per capita                          0.259893  ...                      0.394603
# Social support                          0.204148  ...                      0.456246
# Healthy life expectancy                 0.309666  ...                      0.427892
# Freedom to make life choices            0.080166  ...                      1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
data.head()
# Out:
#              max_infection_rate  ...  Freedom to make life choices
# Afghanistan                 7.0  ...                         0.000
# Albania                     4.0  ...                         0.383
# Algeria                    30.0  ...                         0.086
# Argentina                  13.0  ...                         0.471
# Armenia                     3.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x = data["GDP per capita"]
y = data["max_infection_rate"]
sns.scatterplot(x, np.log(y)) #to balance the scaling issue in the dataset
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#to fit a curve in to the plot above
sns.regplot(x,np.log(y))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/numpy/lib/nanfunctions.py:1390: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = data["Social support"]
y = data["max_infection_rate"]
sns.scatterplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x,np.log(y))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/numpy/lib/nanfunctions.py:1390: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate
